# %%
import yfinance as yf
import pandas as pd
import requests

# %%
url1 = "https://www.fundamentus.com.br/detalhes.php"
url2 = "https://www.fundamentus.com.br/resultado.php"
headers = {
    "User-Agent": "Mozilla/5.0"
}

response1 = requests.get(url1, headers=headers)
response2 = requests.get(url2, headers=headers)

ativos = pd.read_html(response1.text)
tickers = pd.read_html(response2.text)

nome = ativos[0]
indicadores = tickers[0]
# Out:
# C:\Users\Luan Carusi\AppData\Local\Temp\ipykernel_6444\3582044207.py:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   ativos = pd.read_html(response1.text)
# C:\Users\Luan Carusi\AppData\Local\Temp\ipykernel_6444\3582044207.py:11: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tickers = pd.read_html(response2.text)

# %%
indicadores.insert(1, "Nome Comercial", nome["Nome Comercial"])

# %%
# Out:
#       Papel             Nome Comercial   Cotação        P/L   P/VP     PSR  \
# 0     PORP4                     ALLIAR       240        000    000    0000
# 1     IVTT3                 ABC Brasil       000        000    000    0000
# 2     MNSA3                 ABC Brasil       042        000    000    0000
# 3     CFLU4                  AMBEV S/A  1.000,00        000    000    0000
# 4     CSTB3                     ABYARA     15000        000    000    0000
# ..      ...                        ...       ...        ...    ...     ...
# 987   SRNA3                        WLM      1262      66505    140    1229
# 988  UBBR11  WEMBLEY SOCIEDADE ANÔNIMA      1475   1.201,81    391    0000
# 989   UBBR3                Wilson Sons      1800   1.466,61    477    0000
# 990   DXCO3                 YDUQS PART       532   4.136,43    071    0593
# 991   PDTC3                  ZAMP S.A.       146  16.668,00  85962  397549
#
# ...
