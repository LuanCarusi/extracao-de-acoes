# %%
import yfinance as yf
import pandas as pd
import requests

# %%
url = "https://www.fundamentus.com.br/detalhes.php"
headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

tabelas = pd.read_html(response.text)

df = tabelas[0]
# Out:
# C:\Users\Luan Carusi\AppData\Local\Temp\ipykernel_6444\3824361041.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tabelas = pd.read_html(response.text)

# %%
df.drop("Razão Social", axis=1, inplace=True)

# %%
tickers = df['Papel'].tolist()

# %%
tickers = [t + ".SA" for t in tickers]
